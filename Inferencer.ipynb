# %%
# !pip install torch
# !pip install -Uqq fastbook
# !pip install fastbook --upgrade
import fastbook
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.1 MB/s eta 0:00:00
# ...

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
from IPython.display import Image
from IPython.display import HTML

thaimenu=[
"แกงเขียวหวานไก่","แกงเทโพ","แกงเลียง","แกงจืดเต้าหู้หมูสับ","แกงจืดมะระยัดไส้",
"แกงมัสมั่นไก่","แกงส้มกุ้ง","ไก่ผัดเม็ดมะม่วงหิมพานต์","ไข่เจียว","ไข่ดาว",
"ไข่พะโล้","ไข่ลูกเขย","กล้วยบวชชี","ก๋วยเตี๋ยวคั่วไก่","กะหล่ำปลีผัดน้ำปลา",
"กุ้งแม่น้ำเผา","กุ้งอบวุ้นเส้น","ขนมครก","ข้าวเหนียวมะม่วง","ข้าวขาหมู",
"ข้าวคลุกกะปิ","ข้าวซอย","ข้าวผัด","ข้าวผัดกุ้ง","ข้าวมันไก่",
"ข้าวหมกไก่","ต้มข่าไก่","ต้มยำกุ้ง","ทอดมัน","ปอเปี๊ยะทอด",
"ผักบุ้งไฟแดง","ผัดไท","ผัดกะเพรา","ผัดซีอิ๊วเส้นใหญ่","ผัดฟักทองใส่ไข่",
"ผัดมะเขือยาวหมูสับ","ผัดหอยลาย","ฝอยทอง","พะแนงไก่","ยำถั่วพู",
"ยำวุ้นเส้น","ลาบหมู","ส้มตำ","สังขยาฟักทอง","สาคูไส้หมู","หมูปิ้ง","หมูสะเต๊ะ","ห่อหมก"
]


# !npx degit github:GemmyNotJimmy/FoodyDudy FoodyDudy --force
path = Path('FoodyDudy')
learn_inf = load_learner('FoodyDudy/export.pkl')

file = open("FoodyDudy/47thaifood.png", "rb")
image2 = file.read()
image_headline = widgets.Image(value=image2,format='png',width='500')

btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
place1 = widgets.HTML()
# place2 = widgets.HTML()
# place3 = widgets.HTML()
top1 = widgets.HTML('<H1>The Menu:</H1>')
menu_label1 = widgets.HTML('<H1>Upload An Image:</H1>')

# image3_result = widgets.Image()

# file3 = open("foodydudygemmy.png", "rb")
file3 = open("FoodyDudy/foodydudygemmy.png", "rb")
# file3 = open("./thaimenu/0.png", "rb")
image3 = file3.read()
image3_result = widgets.Image(value=image3,format='png',width='300')

def on_data_change(change):
    place1.value = ''
    place2.value = ''
    place3.value = ''
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(256,256))
    pred,pred_idx,probs = learn_inf.predict(img)

    probsdicts = {}
    keys = range(len(probs))
    values = probs
    for i in keys:
            probsdicts[i] = values[i]
    sort_probsdicts = sorted(probsdicts.items(), key=lambda x: x[1], reverse=True)[:3]

    ResultIndex=[0,0,0]
    ResultPercent=[0,0,0]
    j=0
    ResultIndex[0]=10
    for i in sort_probsdicts:
      ResultIndex[j]=i[0]
      x=float(i[1])*100
      ResultPercent[j]=x
      j+=1

    place1.value = "Your Image is:"
    # place2.value = "<H1>Top#2 " + thaimenu[ResultIndex[1]-1] + " : " + str(ResultPercent[1])[:6] + "%</H1>"
    # place3.value = "<H1>Top#3 " + thaimenu[ResultIndex[2]-1] + " : " + str(ResultPercent[2])[:6] + "%</H1>"

    # file3 = open("./thaimenu/" + str(int(pred_idx)) + ".png", "rb")
    file3 = open("FoodyDudy/thaimenu/" + str(int(pred_idx)) + ".png", "rb")
    # file3 = open("/content/gdrive/MyDrive/foodydudy/thaimenu/0.png", "rb")
    image3 = file3.read()
    image3_result.value = image3
    image3_result.width = 500

btn_upload.observe(on_data_change, names=['data'])

display(VBox([top1, image_headline, menu_label1, btn_upload, out_pl, place1,place2,place3,image3_result]))
# Out:
# npx: installed 1 in 0.81s
# > destination directory is not empty. Using --force, continuing
# > cloned GemmyNotJimmy/FoodyDudy#HEAD to FoodyDudy
# ...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
